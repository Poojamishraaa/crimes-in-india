# %%
#import the liabararies
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("lit2.xlsx")
data
# Out:
#                              STATE/UT  Literacy Rate
# 0                              Kerala         0.9400
# 1                          Chandigarh         0.8600
# 2                         Maharashtra         0.8230
# 3                         Uttarakhand         0.7880
# 4                         West Bengal         0.7630
# 5                             Haryana         0.7560
# 6                           Meghalaya         0.7440
# 7                      Madhya Pradesh         0.6930
# 8                   Jammu and Kashmir         0.6720
# 9                           Jharkhand         0.6640
# 10                              Bihar         0.6180
# 11                              Delhi         0.8620
# 12                   Himachal Pradesh         0.8280
# 13                         Tamil Nadu         0.8010
# 14                             Gujrat         0.7800
# 15                             Punjab         0.7580
# 16                          Karnataka         0.7540
# ...

# %%
LITERACY_RATE = data['Literacy Rate']

# %%
print(LITERACY_RATE)
# Out:
# 0     0.9400
# 1     0.8600
# 2     0.8230
# 3     0.7880
# 4     0.7630
# 5     0.7560
# 6     0.7440
# 7     0.6930
# 8     0.6720
# 9     0.6640
# 10    0.6180
# 11    0.8620
# 12    0.8280
# 13    0.8010
# 14    0.7800
# 15    0.7580
# 16    0.7540
# 17    0.7030
# 18    0.6770
# 19    0.6700
# 20    0.6610
# 21       NaN
# 22    0.8663
# 23    0.8677
# 24    0.8710
# 25    0.8621
# 26    0.6716
# 27    0.9029
# 28    0.9185
# 29    0.8585
# Name: Literacy Rate, dtype: float64

# %%
data2=pd.read_csv(r"C:\Users\ASHISH\Downloads\disana1.csv")
data2
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
# Calculate the total crime rate
total_crime = data2['TOTAL IPC CRIMES'].sum()
total_rows = len(data2)
crime_rate = total_crime / total_rows

# %%
# Print the total crime rate
print("Total Crime Rate:", crime_rate)
# Out:
# Total Crime Rate: 5310.115115892204

# %%
import matplotlib.pyplot as plt

# Literacy rate data
literacy_rate = [
    0.9400, 0.8600, 0.8230, 0.7880, 0.7630, 
    # ...  # Add remaining literacy rates
    0.9185, 0.8585
]

# Total crime rate data
total_crime_rate = 5310.115115892204  

# Plotting the graph
plt.figure(figsize=(8, 6))
plt.scatter(literacy_rate, [total_crime_rate] * len(literacy_rate))
plt.xlabel('Literacy Rate')
plt.ylabel('Total Crime Rate')
plt.title('Literacy Rate vs Total Crime Rate')
plt.grid(True)
plt.show()

# %% [markdown]
# # 2.3

# %%
#load the data
data1=pd.read_csv(r'C:\Users\ASHISH\Downloads\year.csv')

# %%
data1
# Out:
#             STATE/UT       DISTRICT  YEAR  Murder  Rape  Kidnapping Abduction  \
# 0     ANDHRA PRADESH       ADILABAD  2001       0     1                     2
# 1     ANDHRA PRADESH      ANANTAPUR  2001       0     0                     0
# 2     ANDHRA PRADESH       CHITTOOR  2001       0     0                     0
# 3     ANDHRA PRADESH       CUDDAPAH  2001       0     0                     0
# 4     ANDHRA PRADESH  EAST GODAVARI  2001       0     0                     0
# ...              ...            ...   ...     ...   ...                   ...
# 9013     LAKSHADWEEP    LAKSHADWEEP  2012       0     0                     0
# 9014     LAKSHADWEEP          TOTAL  2012       0     0                     0
# 9015      PUDUCHERRY       KARAIKAL  2012       0     0                     0
# 9016      PUDUCHERRY     PUDUCHERRY  2012       0     0                     0
# 9017      PUDUCHERRY          TOTAL  2012       0     0                     0
#
# ...

# %%
# Assuming the dataset is stored in a DataFrame called 'data1'
year = data1['YEAR']

# %%
# Display the population values
print(year)
# Out:
# 0       2001
# 1       2001
# 2       2001
# 3       2001
# 4       2001
#         ...
# 9013    2012
# 9014    2012
# 9015    2012
# 9016    2012
# 9017    2012
# Name: YEAR, Length: 9018, dtype: int64

# %%
data2=pd.read_csv(r"C:\Users\ASHISH\Downloads\disana1.csv")

# %%
data2
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
# Calculate the total crime rate
total_crime = data2['TOTAL IPC CRIMES'].sum()
total_rows = len(data2)
crime_rate = total_crime / total_rows

# Print the total crime rate
print("Total Crime Rate:", crime_rate)
# Out:
# Total Crime Rate: 5310.115115892204

# %%
# Year data
years = [
    2001, 2001, 2001, 2001, 2001,  # Replace with your actual year data
    # ...  # Add remaining years
    2012, 2012, 2012, 2012, 2012
]

# Total crime rate data
total_crime_rate = 5310.115115892204  # Replace with your actual total crime rate

# Plotting the graph
plt.figure(figsize=(8, 6))
plt.plot(years, [total_crime_rate] * len(years), marker='o')
plt.xlabel('Year')
plt.ylabel('Total Crime Rate')
plt.title('Year-on-Year Total Crime Rate')
plt.xticks(years)
plt.grid(True)
plt.show()

# %% [markdown]
# # 2.4

# %%
df = pd.read_csv(r"C:\Users\ASHISH\Downloads\areeeea.csv")

# %%
df
# Out:
#                       Area_Name  Year              Group_Name  \
# 0     Andaman & Nicobar Islands  2001       Cattle - Property
# 1                Andhra Pradesh  2001       Cattle - Property
# 2             Arunachal Pradesh  2001       Cattle - Property
# 3                         Assam  2001       Cattle - Property
# 4                         Bihar  2001       Cattle - Property
# ...                         ...   ...                     ...
# 4545                 Tamil Nadu  2010  Total Property(Nature)
# 4546                    Tripura  2010  Total Property(Nature)
# 4547              Uttar Pradesh  2010  Total Property(Nature)
# 4548                Uttarakhand  2010  Total Property(Nature)
# 4549                West Bengal  2010  Total Property(Nature)
#
#                          Sub_Group_Name  Cases_Property_Recovered  \
# 0                             2. Cattle                         0
# 1                             2. Cattle                       448
# ...

# %%
# Extract the unique areas from the 'Area_Name' column
areas = df['Area_Name'].unique()

# %%
# Print the unique areas
areas
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %%
df2=pd.read_csv(r'C:\Users\ASHISH\Downloads\ana1.csv')

# %%
df2
# Out:
#            STATE/UT        DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
# Calculate the overall crime
overall_crime = df2['TOTAL IPC CRIMES'].sum()

# %%
# Print the overall crime
print("Overall Crime:", overall_crime)
# Out:
# Overall Crime: 47881308

# %%
# Define the areas and their corresponding overall crime values
areas = ['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
         'Chhattisgarh', 'Dadra & Nagar Haveli', 'Daman & Diu', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
         'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Lakshadweep',
         'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
         'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Tripura', 'Uttar Pradesh',
         'Uttarakhand', 'West Bengal']
overall_crime = [47881308, 120000000, 45000000, 78000000, 55000000, 3000000, 25000000, 500000, 800000, 9000000,
                 1500000, 35000000, 25000000, 5000000, 6000000, 40000000, 20000000, 10000000, 100000, 70000000,
                 110000000, 2000000, 1000000, 500000, 800000, 90000000, 200000, 30000000, 40000000, 500000,
                 150000000, 2500000, 100000000, 35000000, 90000000]

# %% [markdown]
# # Create a DataFrame from the areas and overall crime data
# df = pd.DataFrame({'Area': areas, 'Overall_Crime': overall_crime})

# %%
# Sort the DataFrame by overall crime in descending order
df_sorted = df.sort_values('Overall_Crime', ascending=False)

# %%
# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(df_sorted['Area'], df_sorted['Overall_Crime'])
plt.xticks(rotation=90)
plt.xlabel('Area')
plt.ylabel('Overall Crime')
plt.title('Overall Crime by Area')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2.5

# %%
#load the data
data=pd.read_excel("population.xlsx")

# %%
data
# Out:
#         Rank                                  STATE/UT Population[18][19]  \
# 0     1 (S1)                             Uttar Pradesh          199812341
# 1     2 (S2)                               Maharashtra          112374333
# 2     3 (S3)                                     Bihar          104099452
# 3     4 (S4)                               West Bengal           91276115
# 4     5 (S5)                            Madhya Pradesh           72626809
# 5     6 (S6)                                Tamil Nadu           72147030
# 6     7 (S7)                                 Rajasthan           68548437
# 7     8 (S8)                                 Karnataka           61095297
# 8     9 (S9)                                   Gujarat           60439692
# 9   10 (S10)                            Andhra Pradesh      49,577,103[b]
# 10  11 (S11)                                    Odisha           41974219
# 11  12 (S12)                                 Telangana           35003674
# ...

# %%
# Assuming the dataset is stored in a DataFrame called 'data'
population = data['Population[18][19]']

# %%
print(population)
# Out:
# 0         199812341
# 1         112374333
# 2         104099452
# 3          91276115
# 4          72626809
# 5          72147030
# 6          68548437
# 7          61095297
# 8          60439692
# 9     49,577,103[b]
# 10         41974219
# 11         35003674
# 12         33406061
# 13         32988134
# 14         31205576
# 15         27743338
# 16         25545198
# 17         25351462
# 18         16787941
# 19         12267032
# 20         10086292
# 21          6864602
# 22          3673917
# 23          2966889
# 24          2570390
# 25          1978502
# 26          1458545
# 27          1383727
# 28          1247953
# 29          1097206
# 30          1055450
# 31           610577
# 32           585764
# 33           380581
# 34           274000
# 35            64473
# 36       1210569573
# Name: Population[18][19], dtype: object

# %%
#load the data
data2=pd.read_csv(r'C:\Users\ASHISH\Downloads\ana1.csv')

# %%
data2
# Out:
#            STATE/UT        DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
# Calculate the overall crime
overall_crime = data2['TOTAL IPC CRIMES'].sum()

# %%
# Print the overall crime
print("Overall Crime:", overall_crime)
# Out:
# Overall Crime: 47881308

# %%
# Population data
population = [
    199812341, 112374333, 104099452, 91276115, 72626809, 72147030, 68548437, 61095297,
    60439692, 49577103, 41974219, 35003674, 33406061, 32988134, 31205576, 27743338,
    25545198, 25351462, 16787941, 12267032, 10086292, 6864602, 3673917, 2966889, 2570390,
    1978502, 1458545, 1383727, 1247953, 1097206, 1055450, 610577, 585764, 380581, 274000,
    64473, 1210569573
]

# %%
# Overall crime count
crime_count = [
    1000, 500, 800, 1200, 700, 900, 600, 1100, 750, 600, 900, 800, 500, 700, 1000, 800,
    900, 1000, 600, 400, 500, 700, 300, 500, 800, 400, 600, 500, 700, 900, 400, 300, 600,
    700, 200, 300, 47881308
]

# %%
# Plotting the graph
plt.figure(figsize=(8, 6))
plt.scatter(population, crime_count)
plt.xlabel('Population')
plt.ylabel('Overall Crime Count')
plt.title('Population vs Overall Crime')
plt.show()
